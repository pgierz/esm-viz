# %% [raw]
# <script>
#   jQuery(document).ready(function($) {
#
#   $(window).on('load', function(){
#     $('#preloader').fadeOut('slow',function(){$(this).remove();});
#   });
#
#   });
# </script>
#
# <style type="text/css">
#   div#preloader { position: fixed;
#       left: 0;
#       top: 0;
#       z-index: 999;
#       width: 100%;
#       height: 100%;
#       overflow: visible;
#       background: #fff url('http://preloaders.net/preloaders/720/Moving%20line.gif') no-repeat center center;
#   }
#
# </style>
#
# <div id="preloader">
#
# </div>

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
# General Imports
from IPython.core.display import display, HTML
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime
# Throw out all warnings: (This is a bad idea, but it makes the website "pretty"!)
import warnings
warnings.filterwarnings("ignore")

# %%
# Get the config file:
import argparse
import os
import sys

from esm_viz.esm_viz import read_simulation_config

CONFIG_FILE = '.config_ipynb'

if os.path.isfile(CONFIG_FILE):
    with open(CONFIG_FILE) as f:
        sys.argv = f.read().split()
else:
    sys.argv = ['test_args.py', '/home/csys/pgierz/.config/monitoring/example.yaml']

parser = argparse.ArgumentParser()
parser.add_argument("input_file", help="Path to the YAML file for configuration.")
args = parser.parse_args()
config = read_simulation_config(args.input_file)
display(HTML('<h1>Monitoring for <code>%s</code></h1>, Last Update %s' % (config['basedir'].split("/")[-1],  now.strftime("%c"))))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a01aa44b153a> in <module>
#       4 import sys
#       5
# ----> 6 from esm_viz.esm_viz import read_simulation_config
#       7
#       8 CONFIG_FILE = '.config_ipynb'
#
# ModuleNotFoundError: No module named 'esm_viz'

# %%
display(HTML('<h1>Monitoring for <code>%s</code></h1> Last Update: <i>%s</i>' % ("Experiment",  datetime.datetime.now().strftime("%c"))))
# Out:
# <h1>Monitoring for <code>Experiment</code></h1> Last Update: <i>Mon May 13 08:27:29 2019</i>
